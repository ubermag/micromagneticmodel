# %% [markdown]
# # Tutorials
#
# ## General information:
#
# - [Installation, testing, and update](installation-testing-update.ipynb)
# - [Support, License, How to cite, and Acknowledgements](other.ipynb)
#
# ## Terms and Containers
#
# - [Deriving energy term](deriving-energy-term.ipynb)
# - [Deriving dynamics term](deriving-dynamics-term.ipynb)
# - [Term parameters](term-parameters.ipynb)
# - [Energy terms and energy equation](energy-terms.ipynb)
# - [Dynamics terms and dynamics equation](dynamics-terms.ipynb)
# - [Multiple energy terms of the same class](same-class-terms.ipynb)
#
# ## Evolvers and drivers
#
# - [Evolvers and drivers](evolver-driver.ipynb)
#
# ## System
#
# - [System](system.ipynb)
#
# ## Constants
#
# - [Constants](constants.ipynb)
